# %%
import pandas as pd

# %%
pd.read_csv("test1.csv")
# Out:
#                    victim  multiple              killer  presumed  \
# 0       Agitu Ideo Gudeta         0      Suleiman Adams         0
# 1       Agitu Ideo Gudeta         0      Suleiman Adams         0
# 2       Agitu Ideo Gudeta         0      Suleiman Adams         0
# 3       Agitu Ideo Gudeta         0      Suleiman Adams         0
# 4       Agitu Ideo Gudeta         0      Suleiman Adams         0
# ..                    ...       ...                 ...       ...
# 688      Ambra Pregnolato         0  Michele Venturelli         0
# 689      Ambra Pregnolato         0  Michele Venturelli         0
# 690  Concetta Di Pasquale         0   Salvatore Plumari         1
# 691  Concetta Di Pasquale         0   Salvatore Plumari         1
# 692  Concetta Di Pasquale         0   Salvatore Plumari         1
#
#         location              date article  \
# 0    Frassilongo  29 dicembre 2020     l_b
# 1    Frassilongo  29 dicembre 2020     l_c
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("gossminn/predict-perception-bertino-cause-concept")

model = AutoModelForSequenceClassification.from_pretrained("gossminn/predict-perception-bertino-cause-concept")
